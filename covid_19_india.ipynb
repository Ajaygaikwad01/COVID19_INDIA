# %%
import pandas as pd

# %%
df=pd.read_csv("covid_19_india.csv")

# %%
df.head(80)
# Out:
#     Sno      Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 0     1  30/01/20  6:00 PM               Kerala                       1
# 1     2  31/01/20  6:00 PM               Kerala                       1
# 2     3  01/02/20  6:00 PM               Kerala                       2
# 3     4  02/02/20  6:00 PM               Kerala                       3
# 4     5  03/02/20  6:00 PM               Kerala                       3
# ..  ...       ...      ...                  ...                     ...
# 75   76  09/03/20  6:00 PM               Kerala                       9
# 76   77  09/03/20  6:00 PM          Maharashtra                       2
# 77   78  09/03/20  6:00 PM               Punjab                       1
# 78   79  09/03/20  6:00 PM            Rajasthan                       1
# 79   80  09/03/20  6:00 PM           Tamil Nadu                       1
#
#    ConfirmedForeignNational  Cured  Deaths  Confirmed
# ...

# %%
df.drop("Sno",axis=1,inplace=True)

# %%
df.rename(columns={"State/UnionTerritory":"State"},inplace=True)

# %%
zone=df.groupby("State").sum()

# %%
orange=zone["Confirmed"]>50000

# %%
red=zone["Confirmed"]>100000

# %%
green=zone["Confirmed"]<50000

# %% [markdown]
# # City under Red zone

# %%
zone[red]
# Out:
#                                     Cured  Deaths  Confirmed
# State
# Andhra Pradesh                     196773    6041     406739
# Assam                              105922     384     189860
# Bihar                              194279    2036     310031
# Cases being reassigned to states        0       0     312487
# Delhi                             1215763   69051    2294798
# Gujarat                            782201   76328    1285959
# Haryana                            209529    5119     361911
# Jammu and Kashmir                  123403    3154     243205
# Karnataka                          194168    6415     391093
# Kerala                              75629     920     141792
# Madhya Pradesh                     370825   26393     591585
# Maharashtra                       2548373  232537    5618635
# Odisha                             129604     677     197198
# Punjab                             130964    4669     199448
# ...

# %% [markdown]
# # total Deaths in red zone

# %%
zone[red]["Deaths"].sum()
# Out:
# 531200

# %% [markdown]
# # Total cured in red zone

# %%
zone[red]["Cured"].sum()
# Out:
# 8956808

# %% [markdown]
# # City under Green zone

# %%
zone[green]
# Out:
#                                           Cured  Deaths  Confirmed
# State
# Andaman and Nicobar Islands                2598       0       3562
# Arunachal Pradesh                           902      11       4256
# Chandigarh                                13636     272      20059
# Dadar Nagar Haveli                           14       0        186
# Dadra and Nagar Haveli and Daman and Diu   1019       0       3209
# Daman & Diu                                   0       0          2
# Goa                                        9435      44      27652
# Himachal Pradesh                          15713     391      27835
# Ladakh                                    10276      34      22967
# Manipur                                    8999       0      24707
# Meghalaya                                  1316      83       2193
# Mizoram                                    1079       0       3895
# Nagaland                                   3530       0       9059
# ...

# %% [markdown]
# # total Deaths in green zone

# %%
zone[green]["Deaths"].sum()
# Out:
# 1074

# %% [markdown]
# # Total cured in green zone

# %%
zone[green]["Cured"].sum()
# Out:
# 98789

# %% [markdown]
# # City under orange zone

# %%
zone[orange]
# Out:
#                                     Cured  Deaths  Confirmed
# State
# Andhra Pradesh                     196773    6041     406739
# Assam                              105922     384     189860
# Bihar                              194279    2036     310031
# Cases being reassigned to states        0       0     312487
# Chhattisgarh                        44901     313      72789
# Delhi                             1215763   69051    2294798
# Gujarat                            782201   76328    1285959
# Haryana                            209529    5119     361911
# Jammu and Kashmir                  123403    3154     243205
# Jharkhand                           44394     516      73348
# Karnataka                          194168    6415     391093
# Kerala                              75629     920     141792
# Madhya Pradesh                     370825   26393     591585
# Maharashtra                       2548373  232537    5618635
# ...

# %% [markdown]
# # Total cured in orange zone

# %%
zone[orange]["Cured"].sum()
# Out:
# 9095223
